# %%
import json

# %%
with open('para.txt', 'r') as fp:
    para = json.load(fp)

# %%
globals().update(para)

# %%
import pandas_datareader.data as web

# %%
symbol = 'WIKI/AAPL'  # or 'AAPL.US'

# %%
import os

os.environ['QUANDL_API_KEY'] = quandl_api

# %%
df = web.DataReader(symbol, 'quandl', '2015-01-01', '2015-01-05')

# %%
df
# Out:
#               Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2015-01-05  108.29  108.65  105.41  106.25  64285491.0         0.0
# 2015-01-02  111.39  111.44  107.35  109.33  53204626.0         0.0
#
#             SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# Date
# 2015-01-05         1.0  102.875953  103.217954  100.139941  100.937944
# 2015-01-02         1.0  105.820966  105.868466  101.982949  103.863957
#
#              AdjVolume
# Date
# 2015-01-05  64285491.0
# 2015-01-02  53204626.0

# %%
df = web.DataReader(symbol, 'quandl', '2015-01-01', '2019-02-28')

# %%
df
# Out:
#                Open      High       Low    Close       Volume  ExDividend  \
# Date
# 2018-03-27  173.680  175.1500  166.9200  168.340   38962839.0        0.00
# 2018-03-26  168.070  173.1000  166.4400  172.770   36272617.0        0.00
# 2018-03-23  168.390  169.9200  164.9400  164.940   40248954.0        0.00
# 2018-03-22  170.000  172.6800  168.6000  168.845   41051076.0        0.00
# 2018-03-21  175.040  175.0900  171.2600  171.270   35247358.0        0.00
# 2018-03-20  175.240  176.8000  174.9400  175.240   19314039.0        0.00
# 2018-03-19  177.320  177.4700  173.6600  175.300   32804695.0        0.00
# 2018-03-16  178.650  179.1200  177.6200  178.020   36836456.0        0.00
# 2018-03-15  178.500  180.2400  178.0701  178.650   22584565.0        0.00
# 2018-03-14  180.320  180.5200  177.8100  178.440   29075469.0        0.00
# 2018-03-13  182.590  183.5000  179.2400  179.970   31168404.0        0.00
# 2018-03-12  180.290  182.3900  180.2100  181.720   32055405.0        0.00
# ...

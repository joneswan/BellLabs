# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
from datetime import datetime as dt

# %%
now = dt.today().strftime("%Y-%m-%d")
print(now)
# Out:
# 2018-11-01

# %%
start_date = '2018-01-01'
end_date = now

# %%
stock_name = 'FCEL'
df = data.DataReader(stock_name, "iex", start_date, end_date)
print(df.head(10))

print(df.describe())

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = df[['close']]

close = close.fillna(method='ffill')
print(close.describe())

# Get the stock timeseries. This now returns a Pandas Series object indexed by date.
stock = close['close']

print(stock[0:10])

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_stock = stock.rolling(window=20).mean()
long_rolling_stock = stock.rolling(window=100).mean()

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(stock.index, stock, label=stock_name)
ax.plot(short_rolling_stock.index, short_rolling_stock, label='20 days rolling')
ax.plot(long_rolling_stock.index, long_rolling_stock, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
# Out:
#             open   high   low  close   volume
# date
# 2018-01-02  1.71  1.740  1.70   1.74   776167
# 2018-01-03  1.76  1.760  1.71   1.73   469868
# 2018-01-04  1.75  1.760  1.74   1.76   622683
# 2018-01-05  1.78  1.785  1.70   1.72   839133
# 2018-01-08  1.71  1.750  1.70   1.74   618955
# 2018-01-09  1.75  1.750  1.71   1.74   817603
# 2018-01-10  1.75  1.930  1.72   1.85  3824751
# 2018-01-11  2.10  2.170  1.93   2.01  8758700
# 2018-01-12  2.08  2.090  1.96   1.98  3380772
# 2018-01-16  2.01  2.030  1.91   1.95  1851830
#              open        high         low       close        volume
# count  211.000000  211.000000  211.000000  211.000000  2.110000e+02
# mean     1.535045    1.565323    1.488879    1.525659  1.114524e+06
# std      0.359674    0.362681    0.353932    0.359960  1.184455e+06
# min      0.781000    0.852000    0.720000    0.785900  2.195370e+05
# 25%      1.140000    1.180000    1.110000    1.145000  6.121815e+05
# 50%      1.680000    1.730000    1.640000    1.670000  8.237580e+05
# 75%      1.850000    1.875000    1.785000    1.840000  1.222598e+06
# max      2.100000    2.170000    2.020000    2.090000  1.259359e+07
#             close
# count  211.000000
# mean     1.525659
# std      0.359960
# min      0.785900
# 25%      1.145000
# 50%      1.670000
# 75%      1.840000
# max      2.090000
# date
# 2018-01-02    1.74
# 2018-01-03    1.73
# 2018-01-04    1.76
# 2018-01-05    1.72
# 2018-01-08    1.74
# 2018-01-09    1.74
# 2018-01-10    1.85
# 2018-01-11    2.01
# 2018-01-12    1.98
# 2018-01-16    1.95
# Name: close, dtype: float64

# %%
now = dt.today().strftime("%Y-%m-%d")
print(now)
# Out:
# 2018-11-02

# %%
start_date = '2018-01-01'
end_date = now

# %%
stock_name = 'FCEL'
df = data.DataReader(stock_name, "iex", start_date, end_date)
print(df.head(10))

print(df.describe())

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = df[['close']]

close = close.fillna(method='ffill')
print(close.describe())

# Get the stock timeseries. This now returns a Pandas Series object indexed by date.
stock = close['close']

print(stock[0:10])

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_stock = stock.rolling(window=20).mean()
long_rolling_stock = stock.rolling(window=100).mean()

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(stock.index, stock, label=stock_name)
ax.plot(short_rolling_stock.index, short_rolling_stock, label='20 days rolling')
ax.plot(long_rolling_stock.index, long_rolling_stock, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
# Out:
#             open   high   low  close   volume
# date
# 2018-01-02  1.71  1.740  1.70   1.74   776167
# 2018-01-03  1.76  1.760  1.71   1.73   469868
# 2018-01-04  1.75  1.760  1.74   1.76   622683
# 2018-01-05  1.78  1.785  1.70   1.72   839133
# 2018-01-08  1.71  1.750  1.70   1.74   618955
# 2018-01-09  1.75  1.750  1.71   1.74   817603
# 2018-01-10  1.75  1.930  1.72   1.85  3824751
# 2018-01-11  2.10  2.170  1.93   2.01  8758700
# 2018-01-12  2.08  2.090  1.96   1.98  3380772
# 2018-01-16  2.01  2.030  1.91   1.95  1851830
#              open        high         low       close        volume
# count  212.000000  212.000000  212.000000  212.000000  2.120000e+02
# mean     1.531956    1.562184    1.485818    1.522655  1.113684e+06
# std      0.361630    0.364695    0.355893    0.361760  1.181709e+06
# min      0.781000    0.852000    0.720000    0.785900  2.195370e+05
# 25%      1.140000    1.177500    1.107500    1.140000  6.143998e+05
# 50%      1.675000    1.725500    1.630000    1.670000  8.237745e+05
# 75%      1.850000    1.872500    1.782500    1.835000  1.221280e+06
# max      2.100000    2.170000    2.020000    2.090000  1.259359e+07
#             close
# count  212.000000
# mean     1.522655
# std      0.361760
# min      0.785900
# 25%      1.140000
# 50%      1.670000
# 75%      1.835000
# max      2.090000
# date
# 2018-01-02    1.74
# 2018-01-03    1.73
# 2018-01-04    1.76
# 2018-01-05    1.72
# 2018-01-08    1.74
# 2018-01-09    1.74
# 2018-01-10    1.85
# 2018-01-11    2.01
# 2018-01-12    1.98
# 2018-01-16    1.95
# Name: close, dtype: float64

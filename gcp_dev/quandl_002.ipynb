# %%
import json
import requests
import pandas as pd
import pandas_datareader.data as web

# %%
with open('para.txt', 'r') as fp:
    para = json.load(fp)

# %%
globals().update(para)

# %%
symbol = 'WIKI/AAPL'  # or 'AAPL.US'

# %%
import os
os.environ['QUANDL_API_KEY'] = quandl_api

# %%
df = web.DataReader(symbol, 'quandl', '2015-01-01', '2015-01-05')

# %%
df
# Out:
#               Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2015-01-05  108.29  108.65  105.41  106.25  64285491.0         0.0
# 2015-01-02  111.39  111.44  107.35  109.33  53204626.0         0.0
#
#             SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# Date
# 2015-01-05         1.0  102.875953  103.217954  100.139941  100.937944
# 2015-01-02         1.0  105.820966  105.868466  101.982949  103.863957
#
#              AdjVolume
# Date
# 2015-01-05  64285491.0
# 2015-01-02  53204626.0

# %%
# curl -X GET -H "Content-Type: application/json; charset=UTF-8" http://10.xx.xx.xx:1234/viratual-networks

# %%
url = "https://www.quandl.com/api/v3/datasets/WIKI/AAPL.json?start_date=1985-05-01&end_date=1997-07-01&order=asc&column_index=4&collapse=quarterly&transformation=rdiff"

# %%
headers = {'content-type': 'application/json'}
response = requests.get(url, headers=headers)

# %%
# response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
json.loads(response.text)
# Out:
# {'dataset': {'id': 9775409,
#   'dataset_code': 'AAPL',
#   'database_code': 'WIKI',
#   'name': 'Apple Inc (AAPL) Prices, Dividends, Splits and Trading Volume',
# ...

# %%
response.json()
# Out:
# {'dataset': {'id': 9775409,
#   'dataset_code': 'AAPL',
#   'database_code': 'WIKI',
#   'name': 'Apple Inc (AAPL) Prices, Dividends, Splits and Trading Volume',
# ...

# %%
data = response.json()

# %%
dataset = data['dataset']

# %%
dataset['column_names']
# Out:
# ['Date', 'Close']

# %%
dataset['data']
# Out:
# [['1985-06-30', 18.0],
#  ['1985-09-30', 15.75],
#  ['1985-12-31', 22.0],
#  ['1986-03-31', 28.25],
#  ['1986-06-30', 35.88],
#  ['1986-09-30', 33.5],
#  ['1986-12-31', 40.5],
#  ['1987-03-31', 64.5],
#  ['1987-06-30', 40.5],
#  ['1987-09-30', 56.5],
#  ['1987-12-31', 42.0],
#  ['1988-03-31', 40.0],
#  ['1988-06-30', 46.25],
#  ['1988-09-30', 43.25],
#  ['1988-12-31', 40.25],
#  ['1989-03-31', 35.63],
#  ['1989-06-30', 41.25],
#  ['1989-09-30', 44.5],
#  ['1989-12-31', 35.25],
#  ['1990-03-31', 40.25],
#  ['1990-06-30', 44.75],
#  ['1990-09-30', 29.0],
#  ['1990-12-31', 43.0],
#  ['1991-03-31', 68.0],
#  ['1991-06-30', 41.5],
#  ['1991-09-30', 49.5],
#  ['1991-12-31', 56.38],
#  ['1992-03-31', 58.25],
#  ['1992-06-30', 48.0],
#  ['1992-09-30', 45.13],
#  ['1992-12-31', 59.75],
#  ['1993-03-31', 51.5],
#  ['1993-06-30', 39.5],
#  ['1993-09-30', 23.37],
#  ['1993-12-31', 29.25],
#  ['1994-03-31', 33.25],
#  ['1994-06-30', 26.5],
#  ['1994-09-30', 33.69],
#  ['1994-12-31', 39.0],
# ...

# %%
df = pd.DataFrame(data = dataset['data'], columns = dataset['column_names'])

# %%
df
# Out:
#           Date  Close
# 0   1985-06-30  18.00
# 1   1985-09-30  15.75
# 2   1985-12-31  22.00
# 3   1986-03-31  28.25
# 4   1986-06-30  35.88
# 5   1986-09-30  33.50
# 6   1986-12-31  40.50
# 7   1987-03-31  64.50
# 8   1987-06-30  40.50
# 9   1987-09-30  56.50
# 10  1987-12-31  42.00
# 11  1988-03-31  40.00
# 12  1988-06-30  46.25
# 13  1988-09-30  43.25
# 14  1988-12-31  40.25
# 15  1989-03-31  35.63
# 16  1989-06-30  41.25
# 17  1989-09-30  44.50
# 18  1989-12-31  35.25
# 19  1990-03-31  40.25
# 20  1990-06-30  44.75
# 21  1990-09-30  29.00
# 22  1990-12-31  43.00
# 23  1991-03-31  68.00
# 24  1991-06-30  41.50
# 25  1991-09-30  49.50
# 26  1991-12-31  56.38
# 27  1992-03-31  58.25
# 28  1992-06-30  48.00
# 29  1992-09-30  45.13
# 30  1992-12-31  59.75
# 31  1993-03-31  51.50
# 32  1993-06-30  39.50
# 33  1993-09-30  23.37
# 34  1993-12-31  29.25
# 35  1994-03-31  33.25
# 36  1994-06-30  26.50
# 37  1994-09-30  33.69
# 38  1994-12-31  39.00
# 39  1995-03-31  35.25
# ...

# %%
sd = '2015-01-01'
ed = '2015-01-31'

# %%
url = "https://www.quandl.com/api/v3/datasets/WIKI/AAPL.json?start_date={0}&end_date={1}&order=asc&column_index=4&transformation=rdiff".format(sd, ed)

# %%
headers = {'content-type': 'application/json'}
response = requests.get(url, headers=headers)

# %%
# response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.json()
# Out:
# {'quandl_error': {'code': 'QELx01',
#   'message': 'You have exceeded the anonymous user limit of 50 calls per day. To make more calls today, please register for a free Quandl account and then include your API key with your requests.'}}

# %%
data = response.json()

# %%
dataset = data['dataset']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = dataset['data'], columns = dataset['column_names'])

# %%
df
# Out:
#           Date   Close
# 0   2015-01-02  109.33
# 1   2015-01-05  106.25
# 2   2015-01-06  106.26
# 3   2015-01-07  107.75
# 4   2015-01-08  111.89
# 5   2015-01-09  112.01
# 6   2015-01-12  109.25
# 7   2015-01-13  110.22
# 8   2015-01-14  109.80
# 9   2015-01-15  106.82
# 10  2015-01-16  105.99
# 11  2015-01-20  108.72
# 12  2015-01-21  109.55
# 13  2015-01-22  112.40
# 14  2015-01-23  112.98
# 15  2015-01-26  113.10
# 16  2015-01-27  109.14
# 17  2015-01-28  115.31
# 18  2015-01-29  118.90
# 19  2015-01-30  117.16

# %% [markdown]
# #### Run everything in one go

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
from datetime import datetime as dt

# %%
now = dt.today().strftime("%Y-%m-%d")
print(now)
# Out:
# 2019-05-29

# %%
start_date = '2017-01-01'
end_date = '2018-12-31'

# %%
symbol = 'WIKI/AAPL'  # or 'AAPL.US'ddd

# %%
df = web.DataReader(symbol, 'quandl', start_date, end_date)

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  ExDividend  \
# Date
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0         0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0         0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0         0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0         0.0
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27         1.0   173.68   175.15  166.92   168.340  38962839.0
# 2018-03-26         1.0   168.07   173.10  166.44   172.770  36272617.0
# 2018-03-23         1.0   168.39   169.92  164.94   164.940  40248954.0
# 2018-03-22         1.0   170.00   172.68  168.60   168.845  41051076.0
# 2018-03-21         1.0   175.04   175.09  171.26   171.270  35247358.0

# %%
df.tail()
# Out:
#               Open      High     Low   Close      Volume  ExDividend  \
# Date
# 2017-01-09  117.95  119.4300  117.94  118.99  33561948.0         0.0
# 2017-01-06  116.78  118.1600  116.47  117.91  31751900.0         0.0
# 2017-01-05  115.92  116.8642  115.81  116.61  22193587.0         0.0
# 2017-01-04  115.85  116.5100  115.75  116.02  21118116.0         0.0
# 2017-01-03  115.80  116.3300  114.76  116.15  28781865.0         0.0
#
#             SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# Date
# 2017-01-09         1.0  116.493145  117.954865  116.483269  117.520300
# 2017-01-06         1.0  115.337596  116.700551  115.031425  116.453639
# 2017-01-05         1.0  114.488219  115.420756  114.379577  115.169696
# 2017-01-04         1.0  114.419083  115.070931  114.320318  114.586983
# 2017-01-03         1.0  114.369701  114.893155  113.342546  114.715378
#
#              AdjVolume
# Date
# 2017-01-09  33561948.0
# 2017-01-06  31751900.0
# 2017-01-05  22193587.0
# ...

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  308.000000  308.000000  308.000000  308.000000  3.080000e+02
# mean   154.561875  155.668499  153.460605  154.620823  2.853796e+07
# std     16.084998   16.266446   15.776503   15.943549  1.214659e+07
# min    115.800000  116.330000  114.760000  116.020000  1.394898e+07
# 25%    143.717500  144.497500  143.087500  143.695000  2.076822e+07
# 50%    155.105000  155.895000  154.025000  155.345000  2.517043e+07
# 75%    169.955000  170.835000  168.410000  169.390500  3.280821e+07
# max    182.590000  183.500000  180.210000  181.720000  1.119850e+08
#
#        ExDividend  SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# count  308.000000       308.0  308.000000  308.000000  308.000000  308.000000
# mean     0.005942         1.0  154.079233  155.182703  152.980295  154.137248
# std      0.060071         0.0   16.572950   16.758365   16.259687   16.431586
# ...

# %%
symbol = 'WIKI/AAPL'  # or 'AAPL.US'
stock_name = 'APPL'
df = web.DataReader(symbol, 'quandl', start_date, end_date)
print(df.head(10))

print(df.describe())

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = df[['Close']]

close = close.fillna(method='ffill')
print(close.describe())

# Get the stock timeseries. This now returns a Pandas Series object indexed by date.
stock = close['Close']

print(stock[0:10])

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_stock = stock.rolling(window=20).mean()
long_rolling_stock = stock.rolling(window=100).mean()

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(stock.index, stock, label=stock_name)
ax.plot(short_rolling_stock.index, short_rolling_stock, label='20 days rolling')
ax.plot(long_rolling_stock.index, long_rolling_stock, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
# Out:
#               Open    High       Low    Close      Volume  ExDividend  \
# Date
# 2018-03-27  173.68  175.15  166.9200  168.340  38962839.0         0.0
# 2018-03-26  168.07  173.10  166.4400  172.770  36272617.0         0.0
# 2018-03-23  168.39  169.92  164.9400  164.940  40248954.0         0.0
# 2018-03-22  170.00  172.68  168.6000  168.845  41051076.0         0.0
# 2018-03-21  175.04  175.09  171.2600  171.270  35247358.0         0.0
# 2018-03-20  175.24  176.80  174.9400  175.240  19314039.0         0.0
# 2018-03-19  177.32  177.47  173.6600  175.300  32804695.0         0.0
# 2018-03-16  178.65  179.12  177.6200  178.020  36836456.0         0.0
# 2018-03-15  178.50  180.24  178.0701  178.650  22584565.0         0.0
# 2018-03-14  180.32  180.52  177.8100  178.440  29075469.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh    AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27         1.0   173.68   175.15  166.9200   168.340  38962839.0
# ...
